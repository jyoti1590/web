# %% [markdown]
# <a href="https://colab.research.google.com/github/jyoti1590/web/blob/main/jyotiwebscraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#install packages requests and bs4
pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)

# %%
pip install bs4
# Out:
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4) (4.6.3)

# %%
#import packages
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderabad-city'
req  = requests.get(url)
soup = BeautifulSoup(req.text,"html")
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta content="text/html; charset=utf-8" http-equiv="Content-type"/><title>Buy Hyderabad Properties, Residential Property for sale in Hyderabad</title><meta content="Residential Properties for sale in Hyderabad - Choose best property from 0 verified and genuine listings on Makaan.com with location map, similar properties, great amenities available for sale online on Makaan.com." name="description"/><meta content="Buy Hyderabad Properties, Residential Property for sale in Hyderabad, Property for sale in Hyderabad, Hyderabad Property Sale" name="keywords"/><meta content="#fff" id="themeColor" name="theme-color"/><meta content="origin" name="referrer"/><meta content="55ce01b3ca93c05fd5a41439a23dd0d9" name="p:domain_verify"/><meta content="155462194517712" name="fb:pages"/><meta content="India" name="country"/><meta content="website" name="og:type"/><meta content="Makaan.com" name="og:site_name"/><meta content="http://static.makaan.com/6/12/355/11020788.jpeg" name="og:image:url"/><meta content="Buy Hyderabad Properties, Residential Property for sale in Hyderabad" name="og:title"/><meta content="all" name="googlebot"/><meta content="Residential Properties for sale in Hyderabad - Choose best property from 0 verified and genuine listings on Makaan.com with location map, similar properties, great amenities available for sale online on Makaan.com." name="og:description"/><meta content="https://static.makaan.com/6/12/355/11020788.jpeg" name="og:image:secure_url"/><meta content="minimum-scale=1.0, width=device-width, initial-scale=1.0, maximum-scale=5.0" name="viewport"/><meta content="Makaan.com" name="Author"/><meta content="index, follow" name="robots"/><meta content="https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderabad-city" name="og:url"/><link as="script" href="//static.makaan.com/scripts/vendor/require.min.js" rel="preload"/><link as="script" href="//static.makaan.com/scripts/main.399488c4.js" rel="preload"/><link as="script" href="//static.makaan.com/scripts/infra.a7ac1784.js" rel="preload"/><link as="script" href="//static.makaan.com/scripts/dependency/commonBundle.dab78bf4.js" rel="preload"/><link as="script" href="//static.makaan.com/scripts/app.485038c1.js" rel="preload"/><link href="https://www.makaan.com/lite/hyderabad-residential-property/buy-property-in-hyderabad-city" rel="amphtml"/><meta content="summary" name="twitter:card"/><meta content="@Makaan" name="twitter:site"/><meta content="@Makaan" name="twitter:creator"/><meta content="Makaan" itemprop="name"/><meta content="Residential Properties for sale in Hyderabad - Choose best property from 0 verified and genuine listings on Makaan.com with location map, similar properties, great amenities available for sale online on Makaan.com." itemprop="description"/><meta content="http://static.makaan.com/6/12/355/11020788.jpeg" itemprop="image"/><link href="//static.makaan.com/apple-touch-icon-precomposed.png" rel="apple-touch-icon-precomposed" sizes="180x180"/><link href="//static.makaan.com/apple-touch-icon-152x152-precomposed.png" rel="apple-touch-icon-precomposed" sizes="152x152"/><link href="//static.makaan.com/apple-touch-icon-120x120-precomposed.png" rel="apple-touch-icon-precomposed" sizes="120x120"/><link href="//static.makaan.com/apple-touch-icon-76x76-precomposed.png" rel="apple-touch-icon-precomposed" sizes="76x76"/><link href="//static.makaan.com/apple-touch-icon-72x72-precomposed.png" rel="apple-touch-icon-precomposed" sizes="72x72"/><link href="//static.makaan.com/apple-touch-icon.png" rel="shortcut icon"/><link href="//content.makaan.com" rel="preconnect"/><link href="//www.google-analytics.com" rel="preconnect"/><link href="//static.makaan.com" rel="preconnect"/><link href="//static.makaan.com" rel="preconnect"/><link href="https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderabad-city" rel="canonical"/><link href="https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderaba ...
# .multiloclity-search-wrap .tag-wrap .srched-tag.no-close-tag:hover .close,.txtbtn.disabled,a.btn.disabled,fieldset[disabled] a.btn{pointer-events:none}body,figure{margin:0}hr,legend{margin-bottom:20px}html{font-family:sans-serif;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}article,aside,details,figcaption,figure,footer,header,hgroup,main,menu,nav,section,summary{display:block}audio,canvas,progress,video{display:inline-block;vertical-align:baseline}audio:not([controls]){display:none;height:0}[hidden],template{display:none}a{background-color:transparent;color:#337ab7;text-decoration:none}.img-thumbnail,body{background-color:#fff}a:active,a:hover{outline:0}b,strong{font-weight:700}h1{font-size:2em}small{font-size:80%}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}.btn,img{vertical-align:middle}sup{top:-.5em}sub{bottom:-.25em}img{border:0}svg:not(:root){overflow:hidden}hr{-webkit-box-sizing:content-box;-moz-box-sizing:content-box;box-sizing:content-box;height:0}*,:after,:before,input[type=checkbox],input[type=radio]{-webkit-box-sizing:border-box;-moz-box-sizing:border-box}pre,textarea{overflow:auto}code,kbd,pre,samp{font-family:monospace,monospace;font-size:1em}button,input,optgroup,select,textarea{color:inherit;font:inherit;margin:0}.img-thumbnail,body,output{line-height:1.42857143}button{overflow:visible}.mdbox,.thdd{overflow-x:hidden}button,select{text-transform:none}button,html input[type=button],input[type=reset],input[type=submit]{-webkit-appearance:button;cursor:pointer}button[disabled],html input[disabled]{cursor:default}button::-moz-focus-inner,input::-moz-focus-inner{border:0;padding:0}input[type=checkbox],input[type=radio]{box-sizing:border-box;padding:0}input[type=number]::-webkit-inner-spin-button,input[type=number]::-webkit-outer-spin-button{height:auto}input[type=search]::-webkit-search-cancel-button,input[type=search]::-webkit-search-decoration{-webkit-appearance:none}table{border-collapse:collapse;border-spacing:0}td,th{padding:0}*,:after,:before{box-sizing:border-box}html{font-size:10px;-webkit-tap-highlight-color:transparent}button,input,select,textarea{font-family:inherit;font-size:inherit;line-height:inherit}a:focus,a:hover{color:#23527c;text-decoration:underline}a:focus{outline:dotted thin;outline:-webkit-focus-ring-color auto 5px;outline-offset:-2px}.img-responsive{display:block;max-width:100%;height:auto}.img-thumbnail,label{display:inline-block;max-width:100%}.img-rounded{border-radius:6px}.img-thumbnail{padding:4px;border:1px solid #ddd;border-radius:4px;-webkit-transition:all .2s ease-in-out;-o-transition:all .2s ease-in-out;transition:all .2s ease-in-out;height:auto}.container,.container-fluid{margin-right:auto;margin-left:auto;padding-left:15px;padding-right:15px}.img-circle{border-radius:50%}hr{margin-top:20px;border:0;border-top:1px solid #eee}@media (min-width:768px){.container{width:750px}}@media (min-width:992px){.container{width:970px}}@media (min-width:1200px){.container{width:1170px}}.row{margin-left:-15px;margin-right:-15px}.col-lg-1,.col-lg-10,.col-lg-11,.col-lg-12,.col-lg-2,.col-lg-3,.col-lg-4,.col-lg-5,.col-lg-6,.col-lg-7,.col-lg-8,.col-lg-9,.col-md-1,.col-md-10,.col-md-11,.col-md-12,.col-md-2,.col-md-3,.col-md-4,.col-md-5,.col-md-6,.col-md-7,.col-md-8,.col-md-9,.col-sm-1,.col-sm-10,.col-sm-11,.col-sm-12,.col-sm-2,.col-sm-3,.col-sm-4,.col-sm-5,.col-sm-6,.col-sm-7,.col-sm-8,.col-sm-9,.col-xs-1,.col-xs-10,.col-xs-11,.col-xs-12,.col-xs-2,.col-xs-3,.col-xs-4,.col-xs-5,.col-xs-6,.col-xs-7,.col-xs-8,.col-xs-9{position:relative;min-height:1px;padding-left:15px;padding-right:15px}fieldset,legend{padding:0;border:0}.col-xs-1,.col-xs-10,.col-xs-11,.col-xs-12,.col-xs-2,.col-xs-3,.col-xs-4,.col-xs-5,.col-xs-6,.col-xs-7,.col-xs-8,.col-xs-9{float:left}.col-xs-12{width:100%}.col-xs-11{width:91.66666667%}.col-xs-10{width:83.33333333%}.col-xs-9{width:75%}.col-xs-8{width:66.66666667%}.col-xs-7{width:58.33333333%}.col-xs-6{width:50%}.col-xs-5{width:41.66666667%}.col-x ...
# </style><script data-type="vernac-meta" type="text/json">
#         {}
#     </script><script type="text/javascript">
#         window.pageData =  {"listingType":"buy","pageType":"CITY_URLS","cityName":"Hyderabad","countryId":1,"cityId":12,"url":"hyderabad-residential-property/buy-property-in-hyderabad-city","trackingKeyword":"City Pages Buy","templateId":"MAKAAN_CITY_LISTING_BUY","showCommercial":false,"displayAreaLabel":"in Hyderabad ","filters":{"listingType":"buy","newOrResale":""},"websiteUrl":"https://www.makaan.com","relativeUrl":"/hyderabad-residential-property/buy-property-in-hyderabad-city","canonicalUrl":"https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderabad-city","currBaseUrl":"https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderabad-city","pageLevelApiURL":{"url":"petra/app/v1/city/12?selector={\"fields\":[\"id\",\"label\",\"overviewUrl\",\"centerLatitude\",\"centerLongitude\"]}","mockUrl":"mock/city"},"pageLevel":"city","hideFooter":false,"h1Title":"properties for sale in Hyderabad","h3Title":"Property for Sale","urlGroupType":"buy","ampUrl":"https://www.makaan.com/lite/hyderabad-residential-property/buy-property-in-hyderabad-city","modulePath":"modules/serp/controller","moduleName":"serp","isSerp":true,"serpType":"listing","isCommercial":false,"sellerMicrosite":"https://seller.makaan.com/","trackPageType":"SERP City"};
#         ;window.JARVIS_URL="https://chat.makaan.com/";window.WEBSITE_URL="https://www.makaan.com/";window.GMAP_KEY="AIzaSyDP_oyX1PcHL3Ru2II2mgJ9AqVCjzFmsgo";window.CDN_URL_CSS="//static.makaan.com/";window.GA_TRACKING_ID="UA-76015021-1";window.ONE_SIGNAL_APP_ID="c7e2df0f-6ddf-4ba2-b12e-b6efe518f131";window.AMPLITUDE_TRACKING_ID="ba84cd9610dfa2cc896814ddcc7c5a73";window.FACEBOOK_PIXEL_TRACKING_ID="1569618043329809";window.IRIS_URL="";window.IRIS_PROJECT_ID="makaanbuyer";window.MIXPANEL_TRACKING_ID="d295cc4b1e79b2c907fdce24a56bc8ab";window.NEW_RELIC_APP_ID="15253815";window.GLOBAL_VIRTUAL_NUMBER="";window.OSM_TILE_URL="https://d18n29khb4v3uu.cloudfront.net/styles/osm-bright/{z}/{x}/{y}.jpg";window.OSM_ROUTER_URL="https://maps.makaan.com/osrm/route/v1";window.EVENT_ROUTER_URL="https://eventrouter.housing.com/";
#         window.isLocal = false;
#         window.keepCSS = ['https://chat.makaan.com/user/css/app.min.css','//static.makaan.com/styles/css/vendor-v2.42241af3.css'];
#         window.AB_TEST = {newLeadForm: false};
#         window.requestIdleCallback = window.requestIdleCallback || function(cb, C) {
#             setTimeout(cb, C?C.timeout:0);
#         };
#         window.serviceWorkerRegisteration = function(cb){
#             if(typeof cb == 'function' && ('serviceWorker' in navigator) && false){
#                 requestIdleCallback(function() {
#                     navigator.serviceWorker.getRegistration().then(function(){
#                         cb();
#                     });
#                 });
#             }
#         };
#         window.numberFormat = {"code":"","id":1,"format":2,"isConnectNow":true,"seoLinks":true};
#         window.fileLoadStart = Date.now();
#     </script><style>
#         @font-face {
#             font-family: 'icomoon';
#             font-display: block;
#             src:url('//static.makaan.com/fonts/icomoon.367bad2d.eot?');
#             src:url('//static.makaan.com/fonts/icomoon.367bad2d.eot?#iefix') format('embedded-opentype'),
#                 url('//static.makaan.com/fonts/icomoon.ce5604b1.woff2?') format('woff2'),
#                 url('//static.makaan.com/fonts/icomoon.3621ed71.woff?') format('woff'),
#                 url('//static.makaan.com/fonts/icomoon.731810b0.ttf?') format('truetype'),
#                 url('//static.makaan.com/fonts/icomoon.805076a7.svg?#icomoon') format('svg');
#             font-weight: normal;
#             font-style: normal;
#             -webkit-font-smoothing: antialiased;
#         }
#     </style><style>
# .neighborhood-wrap .nearby-amenity-wrap .nearbyamenity-tabs .tabitem:focus,.neighborhood-wrap .svglegends-wrap .svgoptions .optionitem:focus,.vom-wrap .nearby-amenity-wrap .nearbyamenity-tabs .tabitem:focus,.vom-wrap .svglegends-wrap .svgoptions .optionitem:focus{outline:0}.rating-bar-wrap{position:relative;line-height:1.25}.rating-bar-wrap .rb-row{display:-ms-flexbox;display:flex;-ms-flex-flow:row nowrap;flex-flow:row nowrap;-ms-flex-pack:start;justify-content:flex-start;-ms-flex-align:center;align-items:center;margin-bottom:3px}.rating-bar-wrap .rb-row .star-icon,.rating-bar-wrap .rb-row .star-number{width:13px;color:#666;font-size:12px;font-weight:500}.rating-bar-wrap .rb-row .star-icon{margin-right:5px}.rating-bar-wrap .rb-row .star-icon:before{content:"â"}.rating-bar-wrap .rb-row .bar-holder{width:calc(100% - 80px)}.rating-bar-wrap .rb-row .bar-holder .bar-bg{width:100%;height:5px;border-radius:20px;overflow:hidden;position:relative;background:#f0f0f0}.rating-bar-wrap .rb-row .bar-holder .bar-bg .fill-bar{height:100%;position:absolute;left:0;top:0;background:#666}.rating-bar-wrap .rb-row .buyer-num-holder{width:50px;color:#999;font-size:11px;text-align:right}.rating-bar-wrap .rb-row .buyer-num-holder span{font-weight:700}.rating-bar-wrap .rb-row:last-child{margin-bottom:0}.gallerywrap.slide-active .img-ldr{display:block}.gallerywrap .btn-next,.gallerywrap .btn-prev{position:absolute;bottom:42%;z-index:3;width:34px;height:34px;border-radius:50%;background:rgba(0,0,0,.5);padding:10px 0 0;text-align:center;color:#fff;font-size:10px;text-shadow:0 2px 2px #666;cursor:pointer}.gallerywrap .btn-next:hover,.gallerywrap .btn-prev:hover{background:rgba(0,0,0,.8)}.gallerywrap .btn-next.disable,.gallerywrap .btn-prev.disable{opacity:.25;cursor:not-allowed;text-shadow:0 1px 1px #666}.gallerywrap .btn-next [class*=" icon-"],.gallerywrap .btn-next [class^=icon-],.gallerywrap .btn-prev [class*=" icon-"],.gallerywrap .btn-prev [class^=icon-]{font-size:14px;font-weight:700}.gallerywrap .btn-next [class*=" icon-"]::before,.gallerywrap .btn-next [class^=icon-]::before,.gallerywrap .btn-prev [class*=" icon-"]::before,.gallerywrap .btn-prev [class^=icon-]::before{color:#fff}.gallerywrap .btn-prev{left:5px;float:none;margin-left:0}.gallerywrap .btn-next{right:5px;float:none;margin-right:0}.gallerywrap .dot-container{position:absolute;bottom:0;max-width:55px;max-height:16px;left:50%;transform:translate(-50%);overflow:hidden}.gallerywrap .dot-container.mar-b{bottom:20px}.gallerywrap .dot-container .dots{transition:all .35s ease}.gallerywrap .dot-container span.dot{background-color:#9B9B9B;border-radius:5px;display:inline-block;height:6px;width:6px;margin:2px;vertical-align:top;transform:scale(1);transition:all .35s ease;box-shadow:0 1px 4px 0 rgba(0,0,0,.2)}.cardLayout:hover,.dummy-fixed-top-banner{box-shadow:0 1px 10px 1px rgba(0,0,0,.15)}.gallerywrap .dot-container span.dot.no-width{margin:0;width:0}.gallerywrap .dot-container span.dot:nth-child(1),.gallerywrap .dot-container span.dot:nth-child(5),.gallerywrap .dot-container span.dot:nth-child(6){transform:scale(.66667)}.gallerywrap .dot-container span.dot.active{background-color:#FFF;transform:scale(1.2)}.img-ldr{position:absolute;top:50%;left:50%;width:30px;height:30px;margin-top:-20px;margin-left:-20px;background-color:rgba(255,255,255,.75);border-radius:50%;color:#fff;font-size:22px;line-height:28px;text-align:center;animation:reverse-spin .7s linear infinite;z-index:10;display:none}.img-ldr i{vertical-align:middle}.img-ldr i [class*=path]{color:#fff;font-family:icomoon}.cardLayout .infoWrap .listing-description h3.seo-hdng,.f-count-wrap h1,.f-count-wrap h2,.phrase-detection .card-container .card-list .card-item .content-box,.sidebarcard .sbc-hdng,.top-sellers .sellerbox-wraper h3,.top-sellers h2{font-family:Roboto,-apple-system,BlinkMacSystemFont,Helvetica Neue,Segoe UI,sans-serif}.dummy-fixed-top-banner{position:relative;height:120px;cursor:pointer;margin:20px 80px 30px;display:-ms-flexb ...
# </style><base href="/"/><script>
# (function(i, s, o, g, r, a, m) {
#     i['GoogleAnalyticsObject'] = r;
#     i[r] = i[r] || function() {
#         (i[r].q = i[r].q || []).push(arguments)
#     }, i[r].l = 1 * new Date();
#     a = s.createElement(o), m = s.getElementsByTagName(o)[0];
#     a.async = 1;
#     a.src = g;
#     m.parentNode.insertBefore(a, m)
# })(window, document, 'script', 'https://www.google-analytics.com/analytics.js', 'ga');
#
# if(window.serviceWorkerRegisteration){
#     window.serviceWorkerRegisteration(function(){
#         ga('set', 'dimension16', true);
#     });
# }
# // ga('create', 'UA-74526872-1', 'auto');
# //set sitespeedsamplerate for better page load time sampling
# ga('create', window.GA_TRACKING_ID, 'auto',{'useAmpClientId': true,'siteSpeedSampleRate': 15});
#
# //function sendPageViewGA(lc, fc) {
#     ga('send', 'pageview', {
#         title: 'SERP City',
#         dimension1: 'SERP City',
#         dimension5:'buy',
#         dimension11: window && window.localStorage && window.localStorage.mkn_lead_userid,
#         dimension19: 'City Pages Buy',
#         dimension26:'12',
#         dimension62: window && window.localStorage && window.localStorage.mkn_lead_userid ? 'Yes' : 'No',
#         dimension71: 'english'
#         //dimension46: lc, //For example 'dimension10': tvc_lc_campaign
#         //dimension47: fc //For example 'dimension11': tvc_fc_campaign
#     });
# //}
# </script></head><body><div class="body-container"><header class="header" data-header="" data-lazymodule="header"><script type="text/x-config">{"environment":"https://seller.makaan.com/"}</script><div class="lsfix clearfix no-padding"><div class="md-overlay" data-type="menudrawer-close"></div><div class="makaan-logo no-padding" data-type="track-logo"> <a class="home-default no-ajaxy" href="/" title="get your home at makaan"><img alt="Real Estate, Property, Buy, Sale, Rent:Makaan.com" itemprop="image" src="data:image/png;base64,..." title="India's fastest growing property site"/></a></div><div class="thoverlay hidden" data-type="overlay-sec" style="z-index: 1000;"></div><div class="buy-rent text-center" data-type="categoryDropdown"><span data-target="categoryPlaceholder">buy</span> <i class="icon-chevron-down"></i><ul class="dd ddbuyrent"><li class="buy active" data-label="buy" data-listing-type="buy" data-type="categoryDropdownOption">Buy</li><li class="rent " data-label="rent" data-listing-type="rent" data-type="categoryDropdownOption">Rent</li></ul></div><div class="search-col multiloclity-search-wrap" data-module="search" id="headerSearchWrapper"><div class="search-wrap "><i class="icon-search srchbtn"><span class="path1"></span><span class="path2"></span></i><div data-lazymodule="typeAhead" id="headerSearchBox"><script type="text/x-config">{"name":"searchTypeAhead","multiselect":["LOCALITY","SUBURB"],"typeaheadResultsDataSource":{"filePath":"services/searchService","serviceName":"SearchService","functionName":"getTypeaheadResults"},"loaderElementClass":"search-loader","templatePath":"doT!modules/typeAhead/views/search","minLength":2,"layoutPreloaded":true}</script><div class="thcontainer"><div class="thoverlay hidden" data-type="overlay-sec"></div><div class="tag-wrap" data-type="tags"><div class="srched-tag js-default-suggestion js-suggestion-tag-dummy no-close-tag hide"><span class="val js-tag"></span><span class="close"></span></div><div class="srched-tag js-capsuleCounter js-suggestion-tag-dummy more-tag hide" data-type="tag-minicount"></div><input aria-label="query-text" class="js-input thinput" data-type="query-text" disabled="disabled" placeholder="loading..." type="text"/></div><div class="thdd" data-type="search-list"></div></div></div></div></div><div class="rhs-links clearfix js-hideonsearch"><ul class="rhs-linklist"><li class="makaan-select hide"><a class="js-makaanSelectLogo " data-href="/makaan-select" data-type="makaan-select-logo"><span class="makaan-select-img"></span></a><div class="makaan-select-tooltip-content"><div class="tooltiptext"></div><div class="arrow-top-middle"></div></div></li><li class="home-loan "><a class="js-homeloanLogo" href="/home-loan"><span class="homeloan-img"></span><span class="txt"> Home Loan</span></a></li><li class="download-s-app"><span class="d-show span-link" data-link-name="download app" data-link-type="Other" data-type="download-app" data-url="/download-mobileapp" title=""><span class="app-img"></span><span class="txt"> Download app</span></span></li><li class="sellersitelink"><a data-link-name="list your property" data-link-type="Other" data-type="track-sell-your-property" href="https://seller.makaan.com/postProperty" target="_blank"><span class="list-icon"></span><span class="txt">Sell/Rent Property<sup> Free</sup></span></a></li><li class="loginlink" data-login-element=""><div class="logininitial-wrap" data-link-name="buyer dashboard" data-link-type="Other" data-type="track-my-journey"><div class="user-img img-box-circular" data-user-image=""><a data-link-type="avatar" href="/my-journey/dashboard" title="dashboard"><span class="initial" data-initial=""></span><span class="avatar"><img alt="" class="hide" src="//static.makaan.com/images/sellerHomePage/avtaar.17607d33.png"/></span></a></div></div><div class="signin hide" data-link-name="log in" data-link-type="user-name" data-type="login">Log In</div><div class="signin m-username hide" data-type="track-my-journey" data-use ...
#     {
#         "projectStatus": "",
#         "beds": "",
#         "budget": "",
#         "totalPages":2784,
#         "listingCount":20
#     }
# </script></div></div></div><aside class="js-top-seller-parent list-sidebar clearfix"><div class="js-to-fix to-fix"> <div class="fallback-container"><div class="sidebarcard move inn" data-type="open-pyr"><div class="sbc-l-col"><h3 class="sbc-hdng">Contact Top Sellers</h3><div class="sbc-txt">Get connected with top sellers for your needs.</div><div class="sbc-link"><span class="pink link">Share your requirements</span></div></div><div class="sbc-r-col"><div class="icon-wrap"><img alt="pyr" data-src="//static.makaan.com/images/pyr.2b719db7.png" src="//static.makaan.com/images/dummyPX.e679fbd4.png" title="pyr"/></div></div><div class="clear"></div></div></div><section class="pp-card-super-parent" data-lazymodule="developerProjects" data-loadon="afterLoad"><script type="text/x-config">{"pageSource": "","developerProjectsPlaceHolder":"[developer-project-placeholder]","className": "","isFeatured": false,"isTrending": false,"isBillboard": true,"isMiniBillboard": false,"isShowcase": false,"isSuggested": false,"isFeaturedDeveloper": false,"isFeaturedNational": false,"isCitySlot": false,"isTopProjects": false,"isSiteTakeover": false}</script><div developer-project-placeholder=""></div></section><section class="pp-card-super-parent" data-lazymodule="developerProjects" data-loadon="afterLoad"><script type="text/x-config">{"pageSource": "","developerProjectsPlaceHolder":"[developer-project-placeholder]","className": "","isFeatured": false,"isTrending": false,"isBillboard": false,"isMiniBillboard": true,"isShowcase": false,"isSuggested": false,"isFeaturedDeveloper": false,"isFeaturedNational": false,"isCitySlot": false,"isTopProjects": false,"isSiteTakeover": false}</script><div developer-project-placeholder=""><img alt="Developer Projects" src="//static.makaan.com/images/googleAdsPlaceholder.9b1458e2.svg" style="width:300px;height:180px;margin-left:25px;"/></div></section><div class="fallback-container"><div class="sidebarcard move in0" itemscope="" itemtype="http://schema.org/Organization"><a class="no-ajaxy cardlink" data-type="download-app" href="/download-mobileapp" itemprop="sameAs" rel="nofollow" target="_blank"><div class="sbc-l-col"><h3 class="sbc-hdng" itemprop="name">Makaan on the go</h3><div class="sbc-txt" itemprop="description">Your home search continues wherever you go, with makaan app.</div><div class="sbc-link"><span class="link">Download app</span></div></div><div class="sbc-r-col"><div class="icon-wrap"><img alt="download-app" data-src="//static.makaan.com/images/download-app.2d5d85e4.png" src="//static.makaan.com/images/dummyPX.e679fbd4.png" title="download-app"/></div></div></a><div class="clear"></div></div></div><section data-lazymodule="allianceAds" data-loadon="inview"><script type="text/x-config">{"isMobile": false,"pageType" : "serpRhs","adsContainer": "[data-alliance-container]"}</script><div class="alliance-main-heading hide "><span class="dark">Event </span> <span class="light"> this month </span></div><div class="alliance-sub-heading hide ">Get best offers on our partner site</div><div data-alliance-container=""></div></section><div class="google-ads js-google-ad-serp"><ins class="adPushupAds" data-ac="..." data-adpcontrol="4dmnu" data-siteid="39038" data-ver="2"></ins></div><div><img alt="Great place to work" data-src="//static.makaan.com/images/gptw_banner.6dfc0f2a.jpeg" height="100" src="//static.makaan.com/images/dummyPX.e679fbd4.png" width="300"/></div></div></aside></div></div></div><section><div data-lazymodule="gallery" data-loadon="event" id="main_gallery_serp" style="position: relative;"><script type="text/x-config">{"id": "main_gallery_serp","onlyGallery": true,"group": true,"gallery": true,"autostart":true,"galleryData": "","fullsize": true,"mobile":"false","pageAllData":"","pageType": "serp" ,"extraData":""}</script></div></section></main><div data-lazymodule="pushNotification" data-loadon="event" id="pushNotification"></div><div class="offline-toaster-popup offline-message-js">You are currently of ...
# location
# advantages</div><div class="basic-btn-wrap"><span class="link" data-type="closePopup">Got it</span></div></div><div class="basic-popup hide" data-role="popup" id="localityScorePopup"><div class="basic-hdr">Locality score</div><div class="basic-desc">Calculated based on presence of neighborhood amenities like Restaurants,
# Schools, Hospitals, Public transportation and
# others</div><div class="basic-btn-wrap"><span class="link" data-type="closePopup">Got it</span></div></div><div class="basic-popup hide" data-role="popup" id="userRequirmentAlertPopup"><div data-lazymodule="alertConfirmBox" data-loadon="afterLoad" id="userRequirmentAlert"></div></div><div class="hide" data-role="popup" id="userRequirmentPopup"></div><div class="sharepopup hide" data-role="popup" id="socilaSharing"><div data-lazymodule="socialSharing" data-loadon="afterLoad"><script type="text/x-config">{"FBAppId":"318016194970891"}</script><div data-social-share-container=""></div></div></div></div><div id="page-popup-container"><div class="popup-overlay"></div><div class="featuredSnippet hide" data-role="popup" id="featuredSnippet"><span class="desc-close" data-type="closePopup">â¨</span><h2>properties for sale in Hyderabad</h2><table class="tbl taxonomySerpSummary"><thead><tr><th>Property</th><th>Asking Price<br/>(EMI)</th><th>Address</th></tr></thead><tbody><tr><td>3 BHK Apartment (2,200 sq ft)</td><td class="taxonomyNoOverflow"><span class="rupee currency"></span>1,27,60,000<br/>(EMI: <span class="rupee currency"></span> 97,955)</td><td><span class="taxonomyOverflow">Om Sree Brilliance,</span><span class="taxonomyOverflow">Sainikpuri,</span> Hyderabad</td></tr><tr><td>4 BHK Villa (3,378 sq ft)</td><td class="taxonomyNoOverflow"><span class="rupee currency"></span>2,19,57,000<br/>(EMI: <span class="rupee currency"></span> 1.68 L)</td><td><span class="taxonomyOverflow">Sreenidhi Luxury Park 2,</span><span class="taxonomyOverflow">Shamshabad,</span> Hyderabad</td></tr><tr><td>3 BHK Apartment (1,636 sq ft)</td><td class="taxonomyNoOverflow"><span class="rupee currency"></span>1,01,43,200<br/>(EMI: <span class="rupee currency"></span> 77,867)</td><td><span class="taxonomyOverflow">Anuhar Art Of Living,</span><span class="taxonomyOverflow">Manikonda,</span> Hyderabad</td></tr><tr><td>3 BHK Apartment (1,817 sq ft)</td><td class="taxonomyNoOverflow"><span class="rupee currency"></span>99,93,500<br/>(EMI: <span class="rupee currency"></span> 76,717)</td><td><span class="taxonomyOverflow">Giridhari Rajakshetra,</span><span class="taxonomyOverflow">Kismatpur,</span> Hyderabad</td></tr><tr><td>2 BHK Apartment (1,295 sq ft)</td><td class="taxonomyNoOverflow"><span class="rupee currency"></span>56,98,000<br/>(EMI: <span class="rupee currency"></span> 43,742)</td><td><span class="taxonomyOverflow">Risinia Trendilla,</span><span class="taxonomyOverflow">Bachupally,</span> Hyderabad</td></tr><tr><td>3 BHK Apartment (1,630 sq ft)</td><td class="taxonomyNoOverflow"><span class="rupee currency"></span>78,23,904<br/>(EMI: <span class="rupee currency"></span> 60,062)</td><td><span class="taxonomyOverflow">Ayati Lake View ,</span><span class="taxonomyOverflow">Chengicherla,</span> Hyderabad</td></tr><tr><td>4 BHK Villa (4,132 sq ft)</td><td class="taxonomyNoOverflow"><span class="rupee currency"></span>3,45,02,200<br/>(EMI: <span class="rupee currency"></span> 2.64 L)</td><td><span class="taxonomyOverflow">Haris Affluence,</span><span class="taxonomyOverflow">LB Nagar,</span> Hyderabad</td></tr><tr><td>4 BHK Villa (3,567 sq ft)</td><td class="taxonomyNoOverflow"><span class="rupee currency"></span>6,42,06,000<br/>(EMI: <span class="rupee currency"></span> 4.92 L)</td><td><span class="taxonomyOverflow">Vessella Meadows,</span><span class="taxonomyOverflow">Narsingi,</span> Hyderabad</td></tr><tr><td>4 BHK Villa (2,540 sq ft)</td><td class="taxonomyNoOverflow"><span class="rupee currency"></span>1,75,26,000<br/>(EMI: <span class="rupee currency"></span> 1.34 L)</td><td><span class="taxonomyOverflow">APR Praveens Crystal Avenue,</span><span class="taxonomyOverflow">Hayathnagar,</span> Hyderabad</td></tr><tr><td>3 BHK Apartment (1,770 sq ft)</td><td class="taxonomyNoOverflow"><span class="rupee currency"></span>1,04,41,230<br/>(EMI: <span class="rupee currency"></span> 80,154)</td><td><span class="taxonomyOverflow">Hallmark Sunnyside,</span><span c ...
#
#         /*!
#         loadCSS: load a CSS file asynchronously.
#         [c]2014 @scottjehl, Filament Group, Inc.
#         Licensed MIT
#         */
#         function loadCSS(href, before, id, media, delay) {
#            "use strict";
#            delay = delay ? delay : 0;
#            var ss = window.document.createElement("link");
#            var ref = before || window.document.getElementsByTagName("script")[0];
#            var sheets = window.document.styleSheets;
#            ss.rel = "stylesheet";
#            ss.href = href;
#            ss.media = "only x";
#            ss.id = id;
#
#            function ready(cb) {
#                if (document.readyState.toLowerCase() === 'complete') {
#                    return cb();
#                }
#                setTimeout(function() {
#                    ready(cb);
#                })
#            }
#            ready(function() {
#                ref.parentNode.insertBefore(ss, ref);
#            });
#
#            var onloadcssdefined = function(cb) {
#                var resolvedHref = ss.href;
#                var i = sheets.length;
#                while (i--) {
#                    if (sheets[i].href === resolvedHref) {
#                        return cb();
#                    }
#                }
#                setTimeout(function() {
#                    onloadcssdefined(cb);
#                })
#            };
#
#            function loadCB() {
#                if (ss.addEventListener) {
#                    ss.removeEventListener("load", loadCB);
#                }
#                ss.media = "all";
#            }
#
#            if (ss.addEventListener) {
#                ss.addEventListener("load", loadCB, {"passive":true});
#            }else{
#                 onloadcssdefined(loadCB);
#            }
#            return ss;
#
#         }
#
#         function loadJS(){
#             function lazyScript(href) {
#                     var app = document.createElement('script');
#                     app.type = 'text/javascript';
#                     app.async = true;
#                     app.src = href;
#                     var x = document.getElementsByTagName('script')[0];
#                     x.parentNode.insertBefore(app, x);
#             }
#             window.removeEventListener("load",loadJS);
#
#             setTimeout(function(){
#                 lazyScript('https://assets-1.housingcdn.com/website/javascripts/uni-user.js');
#             }, 4000);
#             //lazyScript('//static.makaan.com//static.makaan.com//static.makaan.com/scripts/app.js'); //LAZYSCRIPT
#             //lazyScript('//static.makaan.com//static.makaan.com//static.makaan.com/scripts/dependency/commonBundle.js'); //LAZYSCRIPT
#             //lazyScript('//static.makaan.com//static.makaan.com//static.makaan.com/scripts/common/pageLoadTracking.js'); //LAZYSCRIPT
#         }
#
#         window.addEventListener("load", loadJS,{"passive":true});
#    </script><noscript><img alt="Google Analtics Tracking Pixel" src="12"/><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WQK44RJ" style="display:none;visibility:hidden" width="0"></iframe> </noscript><div id="pageBottomCss"><script> loadCSS("//static.makaan.com/styles/css/serp-lazyload.58651ea8.css"); </script></div></body></html>

# %%
print(soup.find('td',attrs={'class':'lbl rate'}))
# Out:
# <td class="lbl rate">5,800 / sq ft</td>

# %%
soup.find('div',attrs={'data-type' : 'price-link'}).text
# Out:
# ' 1.27 Cr'

# %%
# price

p_tag = soup.find_all('div',attrs={'data-type' : 'price-link'})

price_1p = []

for p in p_tag:
  price_1p.append(p.text.strip())

# %%
print(price_1p)
# Out:
# ['1.27 Cr', '2.19 Cr', '1.01 Cr', '99.93 L', '56.98 L', '78.23 L', '3.45 Cr', '6.42 Cr', '1.75 Cr', '1.04 Cr', '7.25 Cr', '74.7 L', '75.13 L', '66.79 L', '99.99 L', '45.09 L', '2.75 Cr', '1.24 Cr', '2.39 Cr', '1.16 Cr']

# %%
#cheack length
len(price_1p)
# Out:
# 20

# %%
price_com = [p.text.strip() for p in p_tag]
price_com
# Out:
# ['1.27 Cr',
#  '2.19 Cr',
#  '1.01 Cr',
#  '99.93 L',
#  '56.98 L',
#  '78.23 L',
#  '3.45 Cr',
#  '6.42 Cr',
#  '1.75 Cr',
#  '1.04 Cr',
#  '7.25 Cr',
#  '74.7 L',
#  '75.13 L',
#  '66.79 L',
#  '99.99 L',
#  '45.09 L',
#  '2.75 Cr',
#  '1.24 Cr',
#  '2.39 Cr',
#  '1.16 Cr']

# %%
# number of bhk
prop=soup.find_all('a',attrs={'class':'typelink','target':'_blank'})
n_bhk = []
for b in prop:
  n_bhk.append(b.span.text.strip())
print(n_bhk)
# Out:
# ['3', '4', '3', '3', '2', '3', '4', '4', '4', '3', '4', '2', '3', '3', 'Residential Plot', 'Residential Plot', '5', '3', '3', '3']

# %%
# area in sqft
a_tag = soup.find_all('td', attrs ={'class':'size'})
area = []

for a in a_tag:
  area.append(a.text.strip())
print(area)
# Out:
# ['2200', '3378', '1636', '1817', '1295', '1630', '4132', '3567', '2540', '1770', '5180', '1437', '1503', '1965', '2250', '1503', '3800', '2294', '2085', '1935']

# %%
# locality
l_tag=soup.find_all('a',attrs={'class':'loclink'})
loc = []
for l in l_tag:
  loc.append(l.text.strip())
print(loc)
# Out:
# ['Sainikpuri, Hyderabad', 'Shamshabad, Hyderabad', 'Manikonda, Hyderabad', 'Kismatpur, Hyderabad', 'Bachupally, Hyderabad', 'Chengicherla, Hyderabad', 'LB Nagar, Hyderabad', 'Narsingi, Hyderabad', 'Hayathnagar, Hyderabad', 'Manchirevula, Hyderabad', 'Kismatpur, Hyderabad', 'Bandlaguda Jagir, Hyderabad', 'Mallampet, Hyderabad', 'Kollur, Hyderabad', 'Sheriguda, Hyderabad', 'Cheeriyal, Hyderabad', 'Shamshabad, Hyderabad', 'Sanath Nagar, Hyderabad', 'Banjara Hills, Hyderabad', 'Tellapur, Hyderabad']

# %%
# price_per_sqft

rate_tag=soup.find_all('td',attrs={'class':'lbl rate'})

rate=[r.text.strip() for r in rate_tag]
print(rate)
# Out:
# ['5,800 / sq ft', '6,500 / sq ft', '6,200 / sq ft', '5,500 / sq ft', '4,400 / sq ft', '4,802 / sq ft', '8,350 / sq ft', '18,000 / sq ft', '6,900 / sq ft', '5,899 / sq ft', '14,000 / sq ft', '5,199 / sq ft', '4,999 / sq ft', '3,399 / sq ft', '4,444 / sq ft', '3,000 / sq ft', '7,236 / sq ft', '5,405 / sq ft', '11,500 / sq ft', '6,000 / sq ft']

# %%
status_tag=soup.find_all('td',attrs={'class':'val'})
status = []
for s in status_tag:
  status.append(s.text.strip())
print(status)
# Out:
# ['Under Construction', 'Under Construction', 'Ready to move', 'Under Construction', 'Under Construction', 'Under Construction', 'Under Construction', 'Under Construction', 'Under Construction', 'Under Construction', 'Under Construction', 'Under Construction', 'Under Construction', 'Under Construction', 'New', 'New', 'Ready to move', 'Under Construction', 'Ready to move', 'Under Construction']

# %%
# status,rate,price_1p,loc,area,n_bhk
print(price_1p)
print(rate)
print(area)
print(n_bhk)
print(loc)
print(status)
# Out:
# ['1.27 Cr', '2.19 Cr', '1.01 Cr', '99.93 L', '56.98 L', '78.23 L', '3.45 Cr', '6.42 Cr', '1.75 Cr', '1.04 Cr', '7.25 Cr', '74.7 L', '75.13 L', '66.79 L', '99.99 L', '45.09 L', '2.75 Cr', '1.24 Cr', '2.39 Cr', '1.16 Cr']
# ['5,800 / sq ft', '6,500 / sq ft', '6,200 / sq ft', '5,500 / sq ft', '4,400 / sq ft', '4,802 / sq ft', '8,350 / sq ft', '18,000 / sq ft', '6,900 / sq ft', '5,899 / sq ft', '14,000 / sq ft', '5,199 / sq ft', '4,999 / sq ft', '3,399 / sq ft', '4,444 / sq ft', '3,000 / sq ft', '7,236 / sq ft', '5,405 / sq ft', '11,500 / sq ft', '6,000 / sq ft']
# ['2200', '3378', '1636', '1817', '1295', '1630', '4132', '3567', '2540', '1770', '5180', '1437', '1503', '1965', '2250', '1503', '3800', '2294', '2085', '1935']
# ['3', '4', '3', '3', '2', '3', '4', '4', '4', '3', '4', '2', '3', '3', 'Residential Plot', 'Residential Plot', '5', '3', '3', '3']
# ['Sainikpuri, Hyderabad', 'Shamshabad, Hyderabad', 'Manikonda, Hyderabad', 'Kismatpur, Hyderabad', 'Bachupally, Hyderabad', 'Chengicherla, Hyderabad', 'LB Nagar, Hyderabad', 'Narsingi, Hyderabad', 'Hayathnagar, Hyderabad', 'Manchirevula, Hyderabad', 'Kismatpur, Hyderabad', 'Bandlaguda Jagir, Hyderabad', 'Mallampet, Hyderabad', 'Kollur, Hyderabad', 'Sheriguda, Hyderabad', 'Cheeriyal, Hyderabad', 'Shamshabad, Hyderabad', 'Sanath Nagar, Hyderabad', 'Banjara Hills, Hyderabad', 'Tellapur, Hyderabad']
# ['Under Construction', 'Under Construction', 'Ready to move', 'Under Construction', 'Under Construction', 'Under Construction', 'Under Construction', 'Under Construction', 'Under Construction', 'Under Construction', 'Under Construction', 'Under Construction', 'Under Construction', 'Under Construction', 'New', 'New', 'Ready to move', 'Under Construction', 'Ready to move', 'Under Construction']

# %%
prop_info = {'Price' : price_1p,
            'Rate_per_sqft' : rate,
            'Area' : area,
            'Num_Bhk' : n_bhk,
            'Locality' : loc,
            'Status' : status}
print(prop_info)
# Out:
# {'Price': ['1.27 Cr', '2.19 Cr', '1.01 Cr', '99.93 L', '56.98 L', '78.23 L', '3.45 Cr', '6.42 Cr', '1.75 Cr', '1.04 Cr', '7.25 Cr', '74.7 L', '75.13 L', '66.79 L', '99.99 L', '45.09 L', '2.75 Cr', '1.24 Cr', '2.39 Cr', '1.16 Cr'], 'Rate_per_sqft': ['5,800 / sq ft', '6,500 / sq ft', '6,200 / sq ft', '5,500 / sq ft', '4,400 / sq ft', '4,802 / sq ft', '8,350 / sq ft', '18,000 / sq ft', '6,900 / sq ft', '5,899 / sq ft', '14,000 / sq ft', '5,199 / sq ft', '4,999 / sq ft', '3,399 / sq ft', '4,444 / sq ft', '3,000 / sq ft', '7,236 / sq ft', '5,405 / sq ft', '11,500 / sq ft', '6,000 / sq ft'], 'Area': ['2200', '3378', '1636', '1817', '1295', '1630', '4132', '3567', '2540', '1770', '5180', '1437', '1503', '1965', '2250', '1503', '3800', '2294', '2085', '1935'], 'Num_Bhk': ['3', '4', '3', '3', '2', '3', '4', '4', '4', '3', '4', '2', '3', '3', 'Residential Plot', 'Residential Plot', '5', '3', '3', '3'], 'Locality': ['Sainikpuri, Hyderabad', 'Shamshabad, Hyderabad', 'Manikonda, Hyderabad', 'Kismatpur, Hyderabad', 'Bachupally, Hyderabad', 'Chengicherla, Hyderabad', 'LB Nagar, Hyderabad', 'Narsingi, Hyderabad', 'Hayathnagar, Hyderabad', 'Manchirevula, Hyderabad', 'Kismatpur, Hyderabad', 'Bandlaguda Jagir, Hyderabad', 'Mallampet, Hyderabad', 'Kollur, Hyderabad', 'Sheriguda, Hyderabad', 'Cheeriyal, Hyderabad', 'Shamshabad, Hyderabad', 'Sanath Nagar, Hyderabad', 'Banjara Hills, Hyderabad', 'Tellapur, Hyderabad'], 'Status': ['Under Construction', 'Under Construction', 'Ready to move', 'Under Construction', 'Under Construction', 'Under Construction', 'Under Construction', 'Under Construction', 'Under Construction', 'Under Construction', 'Under Construction', 'Under Construction', 'Under Construction', 'Under Construction', 'New', 'New', 'Ready to move', 'Under Construction', 'Ready to move', 'Under Construction']}

# %%
import pandas as pd
data = pd.DataFrame(prop_info)

# %%
data
# Out:
#       Price   Rate_per_sqft  ...                     Locality              Status
# 0   1.27 Cr   5,800 / sq ft  ...        Sainikpuri, Hyderabad  Under Construction
# 1   2.19 Cr   6,500 / sq ft  ...        Shamshabad, Hyderabad  Under Construction
# 2   1.01 Cr   6,200 / sq ft  ...         Manikonda, Hyderabad       Ready to move
# 3   99.93 L   5,500 / sq ft  ...         Kismatpur, Hyderabad  Under Construction
# 4   56.98 L   4,400 / sq ft  ...        Bachupally, Hyderabad  Under Construction
# 5   78.23 L   4,802 / sq ft  ...      Chengicherla, Hyderabad  Under Construction
# 6   3.45 Cr   8,350 / sq ft  ...          LB Nagar, Hyderabad  Under Construction
# 7   6.42 Cr  18,000 / sq ft  ...          Narsingi, Hyderabad  Under Construction
# 8   1.75 Cr   6,900 / sq ft  ...       Hayathnagar, Hyderabad  Under Construction
# 9   1.04 Cr   5,899 / sq ft  ...      Manchirevula, Hyderabad  Under Construction
# 10  7.25 Cr  14,000 / sq ft  ...         Kismatpur, Hyderabad  Under Construction
# 11   74.7 L   5,199 / sq ft  ...  Bandlaguda Jagir, Hyderabad  Under Construction
# 12  75.13 L   4,999 / sq ft  ...         Mallampet, Hyderabad  Under Construction
# 13  66.79 L   3,399 / sq ft  ...            Kollur, Hyderabad  Under Construction
# 14  99.99 L   4,444 / sq ft  ...         Sheriguda, Hyderabad                 New
# 15  45.09 L   3,000 / sq ft  ...         Cheeriyal, Hyderabad                 New
# 16  2.75 Cr   7,236 / sq ft  ...        Shamshabad, Hyderabad       Ready to move
# 17  1.24 Cr   5,405 / sq ft  ...      Sanath Nagar, Hyderabad  Under Construction
# 18  2.39 Cr  11,500 / sq ft  ...     Banjara Hills, Hyderabad       Ready to move
# 19  1.16 Cr   6,000 / sq ft  ...          Tellapur, Hyderabad  Under Construction
#
# [20 rows x 6 columns]

# %%
data.to_csv('hyd_properties.csv')

# %%
import time
from IPython.display import clear_output

base_url = 'https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderabad-city?page='

price = []
n_bhk = []
area = []
loc = []
rate_info = []
status = []

for i in range(1,26):

  print(f'Going to scrape the data from the {i} page')
  clear_output(wait=True)
  time.sleep(2)

  url = base_url+str(i)
  # 'https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderabad-city?page=' 

  #request the url and convert into soup object
  req = requests.get(url)
  soup = BeautifulSoup(req.text,'html')

  # price

  p_tag = soup.find_all('div',attrs={'data-type' : 'price-link'})
  for p in p_tag:
    price.append(p.text.strip())


  # number of bhk
  prop=soup.find_all('a',attrs={'class':'typelink','target':'_blank'})
  for b in prop:
    n_bhk.append(b.span.text.strip())
  
  # area in sqft
  a_tag = soup.find_all('td', attrs ={'class':'size'})
  for a in a_tag:
    area.append(a.text.strip())
 
  # locality
  l_tag=soup.find_all('a',attrs={'class':'loclink'})
  for l in l_tag:
    loc.append(l.text.strip())

  # price_per_sqft
  rate_tag=soup.find_all('td',attrs={'class':'lbl rate'})
  rate=[r.text.strip() for r in rate_tag]
  for rt in rate:
    rate_info.append(rt)

  status_tag=soup.find_all('td',attrs={'class':'val'})
  for s in status_tag:
    status.append(s.text.strip())
# Out:
# Going to scrape the data from the 25 page

# %%
prop_info = {'Price' : price,
            'Rate_per_sqft' : rate_info,
            'Area' : area,
            'Num_Bhk' : n_bhk,
            'Locality' : loc,
            'Status' : status}
print(prop_info)
# Out:
# {'Price': ['1.27 Cr', '2.19 Cr', '1.01 Cr', '99.93 L', '56.98 L', '78.23 L', '3.45 Cr', '5.22 Cr', '1.75 Cr', '1.04 Cr', '7.25 Cr', '74.7 L', '75.13 L', '66.79 L', '99.99 L', '45.09 L', '2.75 Cr', '1.24 Cr', '2.39 Cr', '1.16 Cr', '1.02 Cr', '1.15 Cr', '90.75 L', '5.13 Cr', '1.39 Cr', '1.26 Cr', '2.43 Cr', '83.05 L', '64.99 L', '1.5 Cr', '59.27 L', '19.65 L', '96 L', '42.88 L', '2.9 Cr', '1.02 Cr', '1.27 Cr', '2.48 Cr', '81.09 L', '62.7 L', '52.58 L', '62.92 L', '3.12 Cr', '9.39 Cr', '1.56 Cr', '1.04 Cr', '6.65 Cr', '99.24 L', '55.33 L', '58.97 L', '1.39 Cr', '1.62 Cr', '54 L', '1.05 Cr', '2.48 Cr', '89.1 L', '1.27 Cr', '1.27 Cr', '68.75 L', '4.52 Cr', '1.02 Cr', '2.28 Cr', '1.49 Cr', '69.28 L', '1.46 Cr', '95.04 L', '21.24 L', '1.4 Cr', '42.88 L', '2.56 Cr', '1.02 Cr', '1.23 Cr', '2.47 Cr', '77.62 L', '57.86 L', '74.58 L', '62.59 L', '3.34 Cr', '9.66 Cr', '1.97 Cr', '73.73 L', '1.02 Cr', '75.58 L', '44.86 L', '79.99 L', '49.41 L', '54 L', '2.27 Cr', '1.21 Cr', '87.31 L', '1.27 Cr', '85.52 L', '6.21 Cr', '1.39 Cr', '1.52 Cr', '2.45 Cr', '88.99 L', '1.24 Cr', '84.01 L', '22.68 L', '1.24 Cr', '1.47 Cr', '1.4 Cr', '1.22 Cr', '1.61 Cr', '1.2 Cr', '2.16 Cr', '2.47 Cr', '1.08 Cr', '1.13 Cr', '80.47 L', '1.01 Cr', '99.88 L', '96.1 L', '79.42 L', '1.1 Cr', '78.18 L', '1.06 Cr', '1.07 Cr', '63.3 L', '94.71 L', '99.93 L', '1 Cr', '62.7 L', '95.04 L', '57.86 L', '63.3 L', '94.71 L', '94.98 L', '1 Cr', '84.15 L', '95.04 L', '94.98 L', '73.97 L', '84.15 L', '73.97 L', '71.88 L', '71.88 L', '96.73 L', '1.11 Cr', '83.63 L', '92.13 L', '63.03 L', '82.53 L', '1.06 Cr', '69.38 L', '76.33 L', '96.38 L', '60.19 L', '55.29 L', '45.79 L', '52.6 L', '44.49 L', '53.9 L', '62.54 L', '54.57 L', '52.79 L', '6.42 Cr', '6.4 Cr', '5.23 Cr', '8.03 Cr', '7.99 Cr', '70.18 L', '71.4 L', '62.83 L', '87.24 L', '85.34 L', '66.64 L', '76.44 L', '1.43 Cr', '1.65 Cr', '1.95 Cr', '1.74 Cr', '1.93 Cr', '1.51 Cr', '1.15 Cr', '1.42 Cr', '1.66 Cr', '1.53 Cr', '1.15 Cr', '1.75 Cr', '1.52 Cr', '1.27 Cr', '1.74 Cr', '1.55 Cr', '83.92 L', '1.26 Cr', '1.22 Cr', '1.27 Cr', '82.88 L', '1.08 Cr', '95 L', '1.13 Cr', '73.73 L', '1.21 Cr', '1.21 Cr', '1.02 Cr', '1.42 Cr', '83.46 L', '1.21 Cr', '97.33 L', '1.11 Cr', '1.07 Cr', '1.2 Cr', '1.2 Cr', '1.01 Cr', '76.09 L', '1.09 Cr', '1.05 Cr', '76.73 L', '93.78 L', '62.02 L', '65.97 L', '69.28 L', '55.78 L', '82.33 L', '62.53 L', '74.68 L', '80.08 L', '73.78 L', '54.43 L', '67.48 L', '66.13 L', '72.88 L', '79.63 L', '73.33 L', '58.93 L', '85.03 L', '59.38 L', '75.13 L', '72.43 L', '55.33 L', '71.08 L', '75.58 L', '69.28 L', '55.78 L', '77.83 L', '82.33 L', '62.53 L', '74.68 L', '71.53 L', '80.08 L', '84.58 L', '73.78 L', '54.43 L', '67.48 L', '66.13 L', '89.98 L', '72.88 L', '79.63 L', '73.33 L', '58.93 L', '57.13 L', '85.03 L', '59.38 L', '72.43 L', '57.58 L', '71.08 L', '77.83 L', '71.53 L', '84.13 L', '84.58 L', '64.33 L', '89.98 L', '57.13 L', '57.58 L', '77.38 L', '84.13 L', '76.03 L', '64.33 L', '77.38 L', '76.03 L', '76.48 L', '76.48 L', '1.19 Cr', '87.99 L', '1.86 Cr', '1.73 Cr', '1.15 Cr', '1.06 Cr', '1.18 Cr', '1.35 Cr', '1.21 Cr', '1.6 Cr', '97.11 L', '82.06 L', '1.05 Cr', '1.01 Cr', '1.43 Cr', '1.15 Cr', '1.03 Cr', '1.11 Cr', '1.04 Cr', '1 Cr', '1.08 Cr', '1.04 Cr', '1.02 Cr', '76.48 L', '1.06 Cr', '1.1 Cr', '1.04 Cr', '1.02 Cr', '76.48 L', '1.06 Cr', '1.1 Cr', '92.09 L', '1.54 Cr', '1.01 Cr', '1.4 Cr', '32 L', '26.72 L', '48 L', '80.01 L', '42.72 L', '2.96 Cr', '2.51 Cr', '2.2 Cr', '2.54 Cr', '99.3 L', '1.21 Cr', '75.9 L', '1.12 Cr', '1.25 Cr', '1.02 Cr', '1.1 Cr', '1.39 Cr', '1.47 Cr', '1.47 Cr', '1.28 Cr', '1.61 Cr', '1.17 Cr', '92.67 L', '78.37 L', '67.37 L', '78.92 L', '78.65 L', '73.7 L', '67.1 L', '92.4 L', '83.6 L', '69.3 L', '87.45 L', '69.02 L', '98.72 L', '69.57 L', '4.52 Cr', '5.18 Cr', '6.29 Cr', '1.02 Cr', '98.49 L', '98.49 L', '1.04 Cr', '1.04 Cr', '95.5 L', '95.5 L', '2.18 Cr', '1.76 Cr', '1.53 Cr', '1.72 Cr', '22 L', '1.75 Cr', '42 L', '3.13 Cr', '2.21 Cr', '3.12 Cr', '2.42 Cr', '2.42 Cr', '2.52 Cr', '1.28 Cr ...

# %%
import pandas as pd
data = pd.DataFrame(prop_info)

# %%
data
# Out:
#        Price  ...              Status
# 0    1.27 Cr  ...  Under Construction
# 1    2.19 Cr  ...  Under Construction
# 2    1.01 Cr  ...       Ready to move
# 3    99.93 L  ...  Under Construction
# 4    56.98 L  ...  Under Construction
# ..       ...  ...                 ...
# 495  1.14 Cr  ...  Under Construction
# 496     55 L  ...  Under Construction
# 497  63.51 L  ...  Under Construction
# 498  1.59 Cr  ...  Under Construction
# 499  81.95 L  ...  Under Construction
#
# [500 rows x 6 columns]

# %%
data.to_csv('hyd_properties.csv')
